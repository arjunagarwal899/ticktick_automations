# %%
import os
from ticktick_automations.utils.ticktick_api import TickTickClient
from dotenv import load_dotenv

load_dotenv()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# True

# %%
client = TickTickClient(
    client_id=os.getenv("TICKTICK_CLIENT_ID"),
    client_secret=os.getenv("TICKTICK_CLIENT_SECRET"),
    access_token=os.getenv("TICKTICK_ACCESS_TOKEN")
)
client.get_completed_tasks()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# []

# %%
client.temp()
# Out:
# API request failed: 503 Server Error: Service Temporarily Unavailable for url: https://api.ticktick.com/api/v2/project/all/completed
# Response: <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# </body>
# </html>
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /Users/arjun.agarwal/Documents/ticktick_automations/ticktick_automations/utils/ticktick_api.py:2 │
# │ 8 in _make_request                                                                               │
# │                                                                                                  │
# │    25 │   BASE_URL_v2 = "https://api.ticktick.com/api/v2"                                        │
# │    26 │   AUTH_URL = "https://ticktick.com/oauth/token"                                          │
# │    27 │                                                                                          │
# │ ❱  28 │   def __init__(self, client_id: str, client_secret: str, access_token: Optional[str] =   │
# │    29 │   │   """                                                                                │
# │    30 │   │   Initialize TickTick client with OAuth credentials                                  │
# │    31                                                                                            │
# │                                                                                                  │
# │ /Users/arjun.agarwal/miniconda3/envs/ticktick/lib/python3.12/site-packages/requests/models.py:10 │
# │ 21 in raise_for_status                                                                           │
# │                                                                                                  │
# │   1018 │   │   │   )                                                                             │
# │   1019 │   │                                                                                     │
# │   1020 │   │   if http_error_msg:                                                                │
# │ ❱ 1021 │   │   │   raise HTTPError(http_error_msg, response=self)                                │
# │   1022 │                                                                                         │
# │   1023 │   def close(self):                                                                      │
# │   1024 │   │   """Releases the connection back to the pool. Once this method has been            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# HTTPError: 503 Server Error: Service Temporarily Unavailable for url:
# https://api.ticktick.com/api/v2/project/all/completed
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 client.temp()                                                                                │
# │   2                                                                                              │
# │ in temp:9                                                                                        │
# │                                                                                                  │
# │ /Users/arjun.agarwal/Documents/ticktick_automations/ticktick_automations/utils/ticktick_api.py:3 │
# │ 6 in _make_request                                                                               │
# │                                                                                                  │
# │    33 │   │   │   client_id: OAuth client ID                                                     │
# │    34 │   │   │   client_secret: OAuth client secret                                             │
# │    35 │   │   │   access_token: Optional cached access token                                     │
# │ ❱  36 │   │   """                                                                                │
# │    37 │   │   self.client_id = client_id                                                         │
# │    38 │   │   self.client_secret = client_secret                                                 │
# │    39 │   │   self.access_token = access_token                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TickTickAPIError: API request failed: 503 Server Error: Service Temporarily Unavailable for url:
# https://api.ticktick.com/api/v2/project/all/completed

# %%
from ticktick.oauth2 import OAuth2        # OAuth2 Manager
from ticktick.api import TickTickClient   # Main Interface
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 from ticktick.oauth2 import OAuth2        # OAuth2 Manager                                   │
# │   2 from ticktick.api import TickTickClient   # Main Interface                                   │
# │   3                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'ticktick'
